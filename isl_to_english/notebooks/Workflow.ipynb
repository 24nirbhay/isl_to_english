# %%
.venv/scripts/
# Out:
#   Cell In[1], line 1
#     .venv/scripts/activate
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ISL to English Translator — Quick Workflow
#
# This notebook demonstrates the high-level steps: prepare dataset, train model, and run the real-time translator.
#
# Note: Long-running tasks (training/inference) are executed via the CLI to keep the notebook responsive.

# %% [markdown]
# ## 1) Prepare dataset
# Convert images under `data/handsigns/<label>/` into landmark CSVs used for training.
# Run the prepare command in a terminal (notebook kernels may not have camera access):
#
# ```powershell
#
# ```

# %%
# %python app.py prepare

# %% [markdown]
# ## 2) Train model
# Run training via the CLI to use GPU/CUDA if available:
#
# ```powershell
# python app.py train
# ```

# %%
# %python app.py train

# %% [markdown]
# ## 3) Run translator
# After training, run the real-time translator (it will open your webcam):
#
# ```powershell
# python app.py run
# ```

# %%
# %python app.py run
